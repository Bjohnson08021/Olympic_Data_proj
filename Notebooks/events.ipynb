# %%
import pandas as pd
import numpy as np

# %%
previous_olympics_df = pd.read_csv ("../Data_Sets/Summer Olympics Medals 1976-2008/Summer-Olympic-medals-1976-to-2008.csv",  encoding='latin-1')
previous_olympics_df.head()
# Out:
#        City    Year     Sport Discipline           Event  \
# 0  Montreal  1976.0  Aquatics     Diving  3m springboard
# 1  Montreal  1976.0  Aquatics     Diving  3m springboard
# 2  Montreal  1976.0  Aquatics     Diving  3m springboard
# 3  Montreal  1976.0  Aquatics     Diving  3m springboard
# 4  Montreal  1976.0  Aquatics     Diving    10m platform
#
#                     Athlete Gender Country_Code        Country Event_gender  \
# 0           KÖHLER, Christa  Women          GDR   East Germany            W
# 1       KOSENKOV, Aleksandr    Men          URS   Soviet Union            M
# 2      BOGGS, Philip George    Men          USA  United States            M
# 3  CAGNOTTO, Giorgio Franco    Men          ITA          Italy            M
# 4    WILSON, Deborah Keplar  Women          USA  United States            W
#
#     Medal
# 0  Silver
# 1  Bronze
# 2    Gold
# 3  Silver
# 4  Bronze

# %%
#dataframe
#Athlete,year and event

athlete_event = previous_olympics_df[['Sport','Discipline']]
athlete_event
# Out:
#            Sport       Discipline
# 0       Aquatics           Diving
# 1       Aquatics           Diving
# 2       Aquatics           Diving
# 3       Aquatics           Diving
# 4       Aquatics           Diving
# ...          ...              ...
# 15428  Wrestling  Wrestling Gre-R
# 15429  Wrestling  Wrestling Gre-R
# 15430  Wrestling  Wrestling Gre-R
# 15431  Wrestling  Wrestling Gre-R
# 15432  Wrestling  Wrestling Gre-R
#
# [15433 rows x 2 columns]

# %%
athlete_event.drop_duplicates(inplace=True)
athlete_event
# Out:
# C:\Users\Leha\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                    Sport       Discipline
# 0               Aquatics           Diving
# 12              Aquatics         Swimming
# 126             Aquatics       Water polo
# 159              Archery          Archery
# 165            Athletics        Athletics
# 312           Basketball       Basketball
# 384               Boxing           Boxing
# 428        Canoe / Kayak  Canoe / Kayak F
# 485              Cycling     Cycling Road
# 500              Cycling    Cycling Track
# 521           Equestrian         Dressage
# 533           Equestrian         Eventing
# 548           Equestrian          Jumping
# ...

# %%
athlete_event.dropna(inplace=True)
# Out:
# C:\Users\Leha\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
athlete_event2 = pd.DataFrame({"Discipline":["Artistic Gymnastics","Karate","Wrestling","Rhythmic Gymnastics",
                                            "Baseball/Softball", "Artistic Swimming","Beach Volleyball", "Trampoline Gymnastics", "Marathon Swimming", "Canoe Slalom", "Surfing",
                                            "Canoe Sprint", "Cycling BMX Racing", "Rugby Sevens", "Equestrian", "Golf", "Skateboarding", "Modern Pentathlon", "Cycling Mountain Bike", "3x3 Basketball",
                                            "Cycling BMX Freestyle", "Sport Climbing", "Gymnastics","Cross-country skiing","Biathlon","Canoeing","Cycling","Synchronized swimming","Short track speed skating","Speed skating","Alpine skiing","Bobsleigh","Ice hockey","Ski jumping","Luge"],
                              "Sport": ["Gymnastics","Karate","Wrestling","Gymnastics",
                                            "Baseballl", "Swimming","Volleyball", "Gymnastics", "Swimming", "Canoe / Kayak", "Surfing",
                                            "Canoe / Kayak", "Cycling", "Rugby", "Equestrian", "Golf", "Skateboarding", "Modern Pentathlon", "Cycling", "Basketball",
                                            "Cycling", "Sport Climbing", "Gymnastics","Skiing","Skiing","Canoe / Kayak","Cycling","Swimming","Speed Skating","Speed Skating","Skiing","Bobsleigh","Ice Hockey","Ski Jumping","Luge"]})

# %%
athlete_event = athlete_event.append(athlete_event2, ignore_index = True)

athlete_event.index = athlete_event.index + 1

# %%
athlete_event.to_csv("..\Output\events.csv")
