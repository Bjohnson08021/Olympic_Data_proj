# %%
import pandas as pd

# %%
# Read in first file 
previous_olympics_df = pd.read_csv ("../Data_Sets/Summer Olympics Medals 1976-2008/Summer-Olympic-medals-1976-to-2008.csv",  encoding='latin-1')

previous_olympics_df.head()
# Out:
#        City    Year     Sport Discipline           Event  \
# 0  Montreal  1976.0  Aquatics     Diving  3m springboard
# 1  Montreal  1976.0  Aquatics     Diving  3m springboard
# 2  Montreal  1976.0  Aquatics     Diving  3m springboard
# 3  Montreal  1976.0  Aquatics     Diving  3m springboard
# 4  Montreal  1976.0  Aquatics     Diving    10m platform
#
#                     Athlete Gender Country_Code        Country Event_gender  \
# 0           KÖHLER, Christa  Women          GDR   East Germany            W
# 1       KOSENKOV, Aleksandr    Men          URS   Soviet Union            M
# 2      BOGGS, Philip George    Men          USA  United States            M
# 3  CAGNOTTO, Giorgio Franco    Men          ITA          Italy            M
# 4    WILSON, Deborah Keplar  Women          USA  United States            W
#
#     Medal
# 0  Silver
# 1  Bronze
# 2    Gold
# 3  Silver
# 4  Bronze

# %%
# Grab needed columns and set index starting with 1
event_winners_df = previous_olympics_df[['Year','Sport','Discipline','Event','Athlete','Gender','Country','Event_gender','Medal']]

event_winners_df = event_winners_df.drop_duplicates()
event_winners_df = event_winners_df.dropna()

event_winners_df['Year'].astype(int)

event_winners_df.index = event_winners_df.index + 1

event_winners_df
# Out:
#          Year      Sport       Discipline           Event  \
# 1      1976.0   Aquatics           Diving  3m springboard
# 2      1976.0   Aquatics           Diving  3m springboard
# 3      1976.0   Aquatics           Diving  3m springboard
# 4      1976.0   Aquatics           Diving  3m springboard
# 5      1976.0   Aquatics           Diving    10m platform
# ...       ...        ...              ...             ...
# 15429  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15430  2008.0  Wrestling  Wrestling Gre-R       66 - 74kg
# 15431  2008.0  Wrestling  Wrestling Gre-R       55 - 60kg
# 15432  2008.0  Wrestling  Wrestling Gre-R       60 - 66kg
# 15433  2008.0  Wrestling  Wrestling Gre-R      96 - 120kg
#
#                         Athlete Gender        Country Event_gender   Medal
# 1               KÖHLER, Christa  Women   East Germany            W  Silver
# 2           KOSENKOV, Aleksandr    Men   Soviet Union            M  Bronze
# ...

# %%
# Modify Athlete column

# %%
# Save file to output path

event_winners_df.to_csv("../Output/Event_Winners.csv")
